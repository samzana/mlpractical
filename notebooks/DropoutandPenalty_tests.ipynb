# %%
import sys
# sys.path.append('/path/to/mlpractical')
from mlp.test_methods import test_dropout_layer
import numpy as np
import os
os.environ['MLP_DATA_DIR'] = r"C:\Users\samue\mlpractical\data"

fprop_test, fprop_output, fprop_correct, \
bprop_test, bprop_output, bprop_correct = test_dropout_layer()

assert fprop_test == 1.0, (
'The dropout layer fprop functionality test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(fprop_correct, fprop_output, fprop_output-fprop_correct)
)

print("Dropout Layer Fprop Functionality Test Passed")

assert bprop_test == 1.0, (
'The dropout layer bprop functionality test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(bprop_correct, bprop_output, bprop_output-bprop_correct)
)

print("Dropout Layer Bprop Test Passed")
# Out:
# -----------------------------------------------------------
# ValueError                Traceback (most recent call last)
# Cell In[1], line 9
#       5 import os
#       6 os.environ['MLP_DATA_DIR'] = r"C:\Users\samue\mlpractical\data"
#       8 fprop_test, fprop_output, fprop_correct, \
# ----> 9 bprop_test, bprop_output, bprop_correct = test_dropout_layer()
#      11 assert fprop_test == 1.0, (
#      12 'The dropout layer fprop functionality test failed'
#      13 'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
#      14 .format(fprop_correct, fprop_output, fprop_output-fprop_correct)
#      15 )
#      17 print("Dropout Layer Fprop Functionality Test Passed")
#
# File ~\mlpractical\mlp\test_methods.py:27, in test_dropout_layer()
#      23     grads = layer.bprop(inputs=x, outputs=out, grads_wrt_outputs=np.ones(x.shape))
#      25 #     correct_outputs = correct_outputs['dropout']
# ---> 27     fprop_test = np.allclose(correct_outputs['DropoutLayer_fprop'], out)
#      29     bprop_test = np.allclose(correct_outputs['DropoutLayer_bprop'], grads)
#      31     return fprop_test, out, correct_outputs['DropoutLayer_fprop'], bprop_test, grads, correct_outputs['DropoutLayer_bprop']
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2307, in allclose(a, b, rtol, atol, equal_nan)
#    2225 @array_function_dispatch(_allclose_dispatcher)
#    2226 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2227     """
#    2228     Returns True if two arrays are element-wise equal within a tolerance.
#    2229
#    (...)   2305
#    2306     """
# -> 2307     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2308     return builtins.bool(res)
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2417, in isclose(a, b, rtol, atol, equal_nan)
#    2414     y = float(y)
#    2416 with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2417     result = (less_equal(abs(x-y), atol + rtol * abs(y))
#    2418               & isfinite(y)
#    2419               | (x == y))
#    2420     if equal_nan:
#    2421         result |= isnan(x) & isnan(y)
#
# ValueError: operands could not be broadcast together with shapes (32,3,8,8) (50,3,64,64)

# %%
from mlp.test_methods import test_L1_Penalty


call_test, call_output, call_correct, \
grad_test, grad_output, grad_correct = test_L1_Penalty()


assert call_test == 1.0, (
'The call function for L1 Penalty test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(call_correct, call_output, call_output-call_correct)
)

print("L1 Penalty Call Functionality Test Passed")

assert grad_test == 1.0, (
'The grad function for L1 Penalty test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(grad_correct, grad_output, grad_output-grad_correct, grad_output/grad_correct)
)



print("L1 Penalty Grad Function Test Passed")
# Out:
# -----------------------------------------------------------
# ValueError                Traceback (most recent call last)
# Cell In[2], line 5
#       1 from mlp.test_methods import test_L1_Penalty
#       4 call_test, call_output, call_correct, \
# ----> 5 grad_test, grad_output, grad_correct = test_L1_Penalty()
#       8 assert call_test == 1.0, (
#       9 'The call function for L1 Penalty test failed'
#      10 'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
#      11 .format(call_correct, call_output, call_output-call_correct)
#      12 )
#      14 print("L1 Penalty Call Functionality Test Passed")
#
# File ~\mlpractical\mlp\test_methods.py:53, in test_L1_Penalty()
#      49 #     correct_outputs = correct_outputs['l1penalty']
#      51     __call__test = np.allclose(correct_outputs['L1Penalty___call__correct'], out)
# ---> 53     grad_test = np.allclose(correct_outputs['L1Penalty_grad_correct'], grads)
#      55     return __call__test, out, correct_outputs['L1Penalty___call__correct'], grad_test, grads, correct_outputs['L1Penalty_grad_correct']
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2307, in allclose(a, b, rtol, atol, equal_nan)
#    2225 @array_function_dispatch(_allclose_dispatcher)
#    2226 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2227     """
#    2228     Returns True if two arrays are element-wise equal within a tolerance.
#    2229
#    (...)   2305
#    2306     """
# -> 2307     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2308     return builtins.bool(res)
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2417, in isclose(a, b, rtol, atol, equal_nan)
#    2414     y = float(y)
#    2416 with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2417     result = (less_equal(abs(x-y), atol + rtol * abs(y))
#    2418               & isfinite(y)
#    2419               | (x == y))
#    2420     if equal_nan:
#    2421         result |= isnan(x) & isnan(y)
#
# ValueError: operands could not be broadcast together with shapes (32,3,8,8) (50,3,64,64)

# %%
from mlp.test_methods import test_L2_Penalty


call_test, call_output, call_correct, \
grad_test, grad_output, grad_correct = test_L2_Penalty()


assert call_test == 1.0, (
'The call function for L2 Penalty test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(call_correct, call_output, call_output-call_correct)
)

print("L2 Penalty Call Functionality Test Passed")

assert grad_test == 1.0, (
'The grad function for L2 Penalty test failed'
'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
.format(grad_correct, grad_output, grad_output-grad_correct, grad_output/grad_correct)
)



print("L2 Penalty Grad Function Test Passed")
# Out:
# -----------------------------------------------------------
# ValueError                Traceback (most recent call last)
# Cell In[3], line 5
#       1 from mlp.test_methods import test_L2_Penalty
#       4 call_test, call_output, call_correct, \
# ----> 5 grad_test, grad_output, grad_correct = test_L2_Penalty()
#       8 assert call_test == 1.0, (
#       9 'The call function for L2 Penalty test failed'
#      10 'Correct output is \n\n{0}\n\n but returned output is \n\n{1}\n\n difference is \n\n{2}'
#      11 .format(call_correct, call_output, call_output-call_correct)
#      12 )
#      14 print("L2 Penalty Call Functionality Test Passed")
#
# File ~\mlpractical\mlp\test_methods.py:77, in test_L2_Penalty()
#      73 #     correct_outputs = correct_outputs['l2penalty']
#      75     __call__test = np.allclose(correct_outputs['L2Penalty___call__correct'], out)
# ---> 77     grad_test = np.allclose(correct_outputs['L2Penalty_grad_correct'], grads)
#      79     return __call__test, out, correct_outputs['L2Penalty___call__correct'], grad_test, grads, correct_outputs['L2Penalty_grad_correct']
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2307, in allclose(a, b, rtol, atol, equal_nan)
#    2225 @array_function_dispatch(_allclose_dispatcher)
#    2226 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2227     """
#    2228     Returns True if two arrays are element-wise equal within a tolerance.
#    2229
#    (...)   2305
#    2306     """
# -> 2307     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2308     return builtins.bool(res)
#
# File ~\Anaconda3\envs\mlp\Lib\site-packages\numpy\_core\numeric.py:2417, in isclose(a, b, rtol, atol, equal_nan)
#    2414     y = float(y)
#    2416 with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2417     result = (less_equal(abs(x-y), atol + rtol * abs(y))
#    2418               & isfinite(y)
#    2419               | (x == y))
#    2420     if equal_nan:
#    2421         result |= isnan(x) & isnan(y)
#
# ValueError: operands could not be broadcast together with shapes (32,3,8,8) (50,3,64,64)
